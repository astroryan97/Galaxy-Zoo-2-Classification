# %% [markdown]
# # Galaxy Classification - Random Forest

# %%
# Import required packages
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn import metrics
from sklearn.model_selection import RandomizedSearchCV

# %%
from astropy import units as u
from astropy import constants as const
from astropy.visualization import quantity_support
from astropy.coordinates import SkyCoord

# %%
# Import and adjust matplotlib dpi scaling for high res displays
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 200

# %%
df = pd.read_csv('modified_galaxy_zoo_2_data.csv')
df
# Out:
#                      OBJID  ASSEST_ID          RA       DEC gz2_class  \
# 0       587731186203885750     278415    0.006464 -0.092593      Sb2l
# 1       587731187277693072     280232    0.019752  0.781716     SBc2m
# 2       588015510343123099     294272    0.029687  0.857908        Sc
# 3       587731186203951236     278417    0.032579 -0.040578      Sb?t
# 4       587731187277693087     280233    0.042151  0.634290        Ei
# ...                    ...        ...         ...       ...       ...
# 239692  587731187277627616     280223  359.967256  0.671613        Ei
# 239693  587731186740756649     279393  359.969490  0.333354      Sc2m
# 239694  588015509806252115     293021  359.973925  0.556181      Sb2t
# 239695  587731187277627630     280224  359.984922  0.675102     Ei(o)
# 239696  587731187277627636     280225  359.988841  0.715114        Ei
#
#         GZ1_MORPHOLOGY  STAR_FORMING  AGN_LINER  PETROR50_R  PETROR90_R  ...  \
# 0                    0             0          0    1.552346    4.724314  ...
# 1                    0             0          0    4.174540    9.485429  ...
# 2                    0             0          0    1.805935    5.665029  ...
# 3                    0             0          1    4.040482   11.246556  ...
# 4                    0             0          0    1.878149    4.611546  ...
# ...                ...           ...        ...         ...         ...  ...
# 239692               4             0          0    2.209229    5.250726  ...
# 239693               4             0          0    3.130419    6.483614  ...
# 239694               4             0          0    3.303175    9.889430  ...
# 239695               0             0          0    1.966789    6.132270  ...
# 239696               0             0          0    2.385262    7.233043  ...
#
#         REDSHIFT  PETROMAG_MU  PETROMAG_MG  PETROMAG_MR  PETROMAG_MI  \
# 0       0.078132   -18.451681   -20.106420   -20.834558   -21.150173
# 1       0.080365   -19.804232   -21.529858   -22.282389   -22.643412
# 2       0.081550   -18.846533   -20.506390   -21.243180   -21.584341
# 3       0.023671   -18.629040   -19.668825   -20.125076   -20.315216
# 4       0.054114   -17.928638   -19.356077   -20.070858   -20.395535
# ...          ...          ...          ...          ...          ...
# 239692  0.081304   -18.989813   -20.305210   -20.978706   -21.284754
# 239693  0.080469   -19.709562   -20.810030   -21.346203   -21.586780
# 239694  0.080549   -20.075562   -21.657505   -22.350897   -22.666334
# 239695  0.084803   -19.253954   -21.126196   -21.886639   -22.268350
# 239696  0.083980   -18.821735   -20.540117   -21.284680   -21.635927
#
#         PETROMAG_MZ  PETROR50_R_KPC  PETROR50_R_KPC_SIMPLE_BIN  \
# 0        -21.371984        2.294145                         22
# 1        -22.916601        6.329214                         63
# 2        -21.863384        2.774615                         27
# 3        -20.470337        1.929550                         19
# 4        -20.669110        1.977281                         19
# ...             ...             ...                        ...
# 239692   -21.504791        3.384962                         33
# 239693   -21.781790        4.751741                         47
# 239694   -22.908318        5.018529                         50
# 239695   -22.547771        3.130471                         31
# 239696   -21.787445        3.763274                         37
#
#         PETROMAG_MR_SIMPLE_BIN  REDSHIFT_SIMPLE_BIN
# 0                           63                    6
# 1                           34                    7
# 2                           55                    7
# 3                           77                    1
# 4                           78                    4
# ...                        ...                  ...
# 239692                      60                    7
# 239693                      53                    7
# 239694                      32                    7
# 239695                      42                    7
# 239696                      54                    7
#
# [239697 rows x 32 columns]

# %%
ra = df['RA']
dec = df['DEC']
coord = SkyCoord(ra, dec, unit=(u.degree, u.degree), frame = 'icrs')

# %%
fig = plt.figure(figsize=(8,6))
ax = fid.add_subplot(111, projection='mollweide')
ax.scatter(coord.ra.radian, coord.dec.radian, marker = '*', s = 5, color = 'red')
ax.set_xticklabels('14h', '16h', '18h', '20h', '22h', '0h', '2h', '4h', '6h', '8h', '10h')
ax.grid(True)
ax.set_xlabel('Declination (DEC)')
ax.set_ylabel('Right Ascension (RA)')
plt.title('Distribution of Galaxy Zoo 2 Galaxies on the Sky')

# %%
df.gz2_class.unique()
# Out:
# array(['Sb2l', 'SBc2m', 'Sc', 'Sb?t', 'Ei', 'Sc2t', 'Sb1t', 'Sc?t',
#        'SBb2m(r)', 'Er', 'Sb', 'Sb?m', 'SBb3m', 'SBc3t', 'SBc4l(i)',
#        'Ser', 'SBd?t', 'Sc(m)', 'Sb?t(r)', 'Sc?m', 'SBc2t', 'SBc?m', 'Ec',
#        'Sb2m', 'Sc3t', 'Ei(o)', 'SBb2l', 'SBb?t', 'SBc?t', 'Sc1t',
#        'Sb(o)', 'Sc3m', 'SBc2l', 'SBb?m', 'Sen', 'Sb2t', 'Sc1m(r)',
#        'SBb2t', 'SBb?m(r)', 'Sc+t', 'Sb(m)', 'SBb2m', 'Sb2m(r)',
#        'Sc1t(d)', 'Sb1l(i)', 'SBb2t(r)', 'SBc4t', 'SBc3m', 'Sc(r)',
#        'Sb1l(m)', 'SBc2t(r)', 'Sb3t', 'Sc?l', 'Sc2m', 'SBc2m(o)', 'SBd1t',
#        'SBc?m(d)', 'Sb?l', 'SBb?t(r)', 'Sa', 'Ec(i)', 'Ser(r)', 'Sa+t(o)',
#        'Sd2l(i)', 'Sc?m(i)', 'Sc2l', 'SBb+t', 'SBb4m', 'SBc3t(r)', 'SBb',
#        'Sa(o)', 'SBc(m)', 'SBc2m(r)', 'Sb(r)', 'Ei(m)', 'Ei(u)',
#        'Sc1m(m)', 'Er(r)', 'Sb?l(d)', 'Sb?m(r)', 'SBc?m(i)', 'Sb2t(r)',
#        'Sb1m(d)', 'Er(m)', 'SBc1m(i)', 'Sb?m(i)', 'SBc', 'Sc2t(r)',
#        'SBb3t', 'Sc4t', 'Sc2t(m)', 'SBb2m(d)', 'Sc?t(m)', 'Sb?m(m)',
#        'Sb3l(m)', 'SBb2m(m)', 'SBc?m(m)', 'SBd2t', 'Sb(i)', 'Sb?m(u)',
#        'Sb?t(u)', 'SBc2m(m)', 'SBb2m(o)', 'SBb1t(r)', 'Sb1m', 'Sc2t(o)',
#        'Ec(o)', 'Sd?t', 'Er(o)', 'Ser(m)', 'SBc4m(i)', 'Sc1l', 'SBc2t(d)',
#        'Sc?t(i)', 'Sc?l(o)', 'Sb+m', 'SBd2l', 'Sc2t(i)', 'Sc?m(m)',
#        'SBc2l(i)', 'Sb?t(m)', 'Sc?t(r)', 'Ei(r)', 'Sc(i)', 'SBd2l(i)',
#        'Sc?m(o)', 'Sc+m(i)', 'Sc?m(r)', 'Sd', 'Sb2t(i)', 'Sd2m', 'Sc3l',
#        'Sc4m', 'Sb?t(o)', 'Sc(o)', 'SBb1l', 'Sb(d)', 'A', 'SBc4m',
#        'SBd2m', 'Ei(i)', 'Sb+t', 'Sb4t(r)', 'Sc3t(r)', 'SBb?l', 'Sb1l',
#        'Ei(d)', 'SBc1m', 'SBc+t', 'Er(u)', 'SBb+t(r)', 'Sb?l(l)', 'SBb1m',
#        'SBc?t(m)', 'SBc?t(r)', 'Sc2l(o)', 'Sc2m(m)', 'Sc+m', 'Sc2l(i)',
#        'Sc3m(o)', 'Sc4l(m)', 'SBb+t(m)', 'Sb2l(u)', 'Sc1l(m)', 'SBa2l(m)',
#        'Sd(i)', 'Sc1t(r)', 'Sa(m)', 'SBb(r)', 'Sd2m(i)', 'Sa(r)', 'SBd4m',
#        'Sc1l(d)', 'SBb2l(i)', 'Sb4t', 'Sc2l(r)', 'SBc?l', 'SBb1l(m)',
#        'Sd?m', 'Sc?t(d)', 'Sd2l', 'Sc4m(d)', 'Sc1m(i)', 'Sb1t(r)',
#        'Sc1l(r)', 'SBc2m(i)', 'SBb(m)', 'SBd(i)', 'Ser(u)', 'SBc3l',
#        'SBb?l(r)', 'Sc?t(u)', 'Sb3t(d)', 'Sc2l(d)', 'Sc?t(o)', 'SBb?t(m)',
#        'Sb?t(d)', 'Sd?t(i)', 'SBc?m(r)', 'SBc2m(d)', 'SBb2l(r)',
#        'SBc?t(o)', 'SBc2l(r)', 'Sd2t', 'Sc2m(i)', 'Sb(u)', 'SBb1t',
#        'SBb4m(r)', 'SBc1t', 'Sb?m(o)', 'SBc3m(d)', 'SBc(r)', 'Sc1t(i)',
#        'Sb+m(r)', 'Sc3t(m)', 'SBb2l(m)', 'SBb3m(r)', 'Sb2l(r)', 'Sc?l(m)',
#        'Sd?m(i)', 'Sa?t', 'Sb2l(m)', 'SBb?t(i)', 'SBc2t(m)', 'Sb+l',
#        'Sb2m(u)', 'Sc2m(r)', 'SBb2l(d)', 'SBb(o)', 'Sc2l(m)', 'Sc3m(r)',
#        'Sd1l(i)', 'Sb?l(o)', 'SBb?m(i)', 'Ser(i)', 'SBb3l(i)', 'Sb3t(r)',
#        'Sc(u)', 'SBc?l(i)', 'Sb?l(u)', 'Sc4m(r)', 'Sb3l', 'SBb4t',
#        'Sc+t(m)', 'Sen(o)', 'Sb2m(m)', 'Sb4m', 'SBc(i)', 'SBb3m(u)',
#        'Sc2m(d)', 'Ser(d)', 'Sc3m(i)', 'SBc1t(r)', 'Er(l)', 'Sc2m(o)',
#        'Sb1t(m)', 'Sen(i)', 'SBd?l(d)', 'SBb?l(u)', 'Sb2m(o)', 'Sc4l',
#        'Sd1m(i)', 'SBc3l(d)', 'SBc(d)', 'Sd+t', 'Sd?l', 'Sc1m(o)',
#        'Ser(o)', 'Sb2l(d)', 'SBb4l', 'SBc3m(m)', 'SBc2t(o)', 'Sb3m',
#        'SBc4t(r)', 'SBc(o)', 'SBc2l(o)', 'SBc+m', 'SBb+m', 'Sa2m',
#        'SBc4t(d)', 'SBd', 'Sc+l', 'Sd?l(i)', 'Sa1m', 'SBc?t(d)', 'SBa2m',
#        'Sb?t(i)', 'Sd4t(i)', 'Seb', 'Sa2l', 'Sc1t(m)', 'SBb3m(i)',
#        'Sc4m(i)', 'Sd?m(r)', 'Sd?l(m)', 'Sc2t(u)', 'SBc3m(r)', 'SBc?l(o)',
#        'Sd2m(o)', 'Sc3m(m)', 'SBb+l', 'SBd?m', 'SBc?t(i)', 'SBc3t(o)',
#        'SBb?m(u)', 'Sb+l(o)', 'Sd(o)', 'SBb?m(d)', 'Seb(m)', 'Sb?l(m)',
#        'SBc2l(m)', 'Sb1l(l)', 'SBc1l(i)', 'Sc1m', 'SBb3l', 'Sc(d)',
#        'Sb3m(m)', 'Sc?l(d)', 'SBb?m(m)', 'SBc(l)', 'Sb2m(d)', 'Sb4l(r)',
#        'Sd2l(d)', 'Sb2l(o)', 'SBc3m(o)', 'Ec(r)', 'Sc3t(d)', 'Sd?t(r)',
#        'Sd+m(d)', 'SBb1l(r)', 'Sd?t(o)', 'Er(i)', 'SBb2m(i)', 'Sc?l(i)',
#        'Sc3m(d)', 'Sc4t(d)', 'Sb1m(r)', 'Sb+t(o)', 'SBc4l', 'SBd3m',
#        'Sd?t(d)', 'SBc1l', 'Sb?l(r)', 'Sc3t(o)', 'SBd2m(d)', 'Sb3t(m)',
#        'SBc4t(m)', 'Sd(r)', 'Sb4m(r)', 'SBa1t', 'Sd4t', 'Sb2m(i)',
#        'Sb1t(i)', 'Sd(m)', 'Sa+t', 'SBd+m', 'Ec(d)', 'SBc+m(o)',
#        'SBc1m(r)', 'Sd3t', 'Sb1m(o)', 'Sc4m(o)', 'SBb2m(l)', 'Sb3l(r)',
#        'SBa(r)', 'SBb?t(u)', 'SBb3t(r)', 'Er(d)', 'Sb2l(l)', 'Sd(d)',
#        'SBc+t(r)', 'Sc+t(o)', 'SBb2t(o)', 'Sen(u)', 'SBc3t(m)', 'Ei(l)',
#        'SBc?m(o)', 'Sb2t(m)', 'Sb2t(d)', 'Sb1m(m)', 'SBc3t(u)', 'Sc4t(o)',
#        'SBa?t', 'Sd3m(i)', 'Sb3t(i)', 'SBb?t(o)', 'SBb1l(d)', 'Sb2l(i)',
#        'Sc?m(d)', 'SBc4t(i)', 'SBb4t(i)', 'SBc1l(m)', 'SBc?t(u)', 'SBa2l',
#        'SBb2l(u)', 'Sd4m', 'Sc1l(u)', 'Sd+m(i)', 'Sb1l(d)', 'Sa2t(i)',
#        'SBb1l(o)', 'Sd3m', 'SBd(o)', 'SBc4m(o)', 'SBb2t(m)', 'SBd2l(m)',
#        'SBb(i)', 'SBb(d)', 'Sc(l)', 'SBc1t(i)', 'Sc3t(i)', 'Sa1t',
#        'SBb1l(i)', 'Sc1l(i)', 'Sc+m(o)', 'SBd?l', 'SBc2t(i)', 'SBa1t(i)',
#        'Sc?m(u)', 'Sb1l(r)', 'Sb1t(d)', 'Sb+t(l)', 'SBd?t(m)', 'Sa1m(d)',
#        'SBd2m(i)', 'Sb4t(m)', 'Sen(m)', 'Sc3l(d)', 'SBb2l(o)', 'Sd2t(i)',
#        'SBa?m', 'Sb1t(u)', 'Sd1m', 'SBb3l(r)', 'Ec(u)', 'Sd2t(r)',
#        'SBd?t(i)', 'Sb?t(l)', 'SBc2l(d)', 'Sc1l(o)', 'Sa2t(r)',
#        'SBb3t(u)', 'Sb1t(o)', 'SBc(u)', 'SBc1t(d)', 'Ec(m)', 'SBc?l(r)',
#        'SBb4t(m)', 'Sb3l(i)', 'Sc+t(r)', 'SBb4t(r)', 'SBa?l', 'SBb3m(o)',
#        'Sd?l(d)', 'SBc1l(d)', 'SBd3m(i)', 'Sb(l)', 'Sc+t(i)', 'Sc?t(l)',
#        'SBc+t(o)', 'SBc+t(m)', 'SBc1m(d)', 'SBc2m(l)', 'Sb3m(r)',
#        'SBb?t(d)', 'SBc1l(r)', 'Sb3m(d)', 'SBc3m(i)', 'SBa4m', 'SBc3t(i)',
#        'SBb+l(o)', 'Sc3l(i)', 'Sb4m(m)', 'SBd?t(r)', 'SBb+t(o)',
#        'SBb4m(m)', 'Sb1m(i)', 'SBc3t(d)', 'SBa', 'Sb?l(i)', 'Sd?m(m)',
#        'Sc2t(d)', 'SBb(u)', 'SBb1m(r)', 'Sc2l(u)', 'SBc3m(u)', 'Sc2m(u)',
#        'SBc+l(d)', 'Sb1l(o)', 'SBb3t(i)', 'Sc4t(r)', 'SBd(d)', 'Sa1t(o)',
#        'SBb?l(i)', 'Sb3m(i)', 'SBb3m(m)', 'Sc+m(d)', 'SBc3l(i)',
#        'Sb2t(o)', 'SBb4m(i)', 'SBb2t(d)', 'Sb3t(o)', 'SBb1m(m)',
#        'Sc?l(r)', 'Sb4t(o)', 'SBd(r)', 'Sa?m', 'Sa2t', 'Sc4l(r)',
#        'Sa?t(m)', 'SBc+t(i)', 'Sb+t(m)', 'Sc1m(d)', 'Ser(l)', 'SBd2l(d)',
#        'Sc2m(l)', 'Sb+m(o)', 'Sc4t(i)', 'Sc3l(r)', 'Sd+l', 'Sc4m(m)',
#        'Sc+l(r)', 'Sb+m(l)', 'Sd1t(i)', 'SBb3t(m)', 'Sc2t(l)', 'Sa3m(d)',
#        'Sb?m(d)', 'Sa(u)', 'SBb1l(u)', 'SBc?l(d)', 'SBa1m', 'Sc2l(l)',
#        'Sc?l(l)', 'Sd1l', 'Sc1t(u)', 'SBb?l(o)', 'Sc1l(l)', 'Sd(u)',
#        'Sd2t(o)', 'Sd1l(o)', 'Sb3l(o)', 'SBc?m(l)', 'Sb+t(r)', 'Sa3t',
#        'SBd1l(d)', 'SBd?m(o)', 'Sd1t', 'Sb2t(l)', 'Sb4l', 'Sb3l(d)',
#        'Sb4l(i)', 'Sb3m(o)', 'SBd3t', 'SBc+l', 'Sb4m(o)', 'SBb?m(o)',
#        'SBd(m)', 'Sd4l', 'Sc3t(u)', 'SBd?m(i)', 'SBc1t(m)', 'Sb1m(l)',
#        'SBa2m(m)', 'Sc1m(u)', 'SBc4m(d)', 'SBd2t(u)', 'SBa1l(m)',
#        'Sd4m(i)', 'SBc1m(m)', 'SBb1t(m)', 'SBc2t(u)', 'Sa?l(m)',
#        'SBc1t(o)', 'Sa1l(r)', 'SBb+l(r)', 'SBb+t(i)', 'Sd1t(d)',
#        'Sb1l(u)', 'Sa(d)', 'Sc4l(i)', 'SBb1m(u)', 'SBc2m(u)', 'Sb+m(i)',
#        'Sa?t(r)', 'SBb?m(l)', 'Sc+t(d)', 'Sc3t(l)', 'Sc1t(l)', 'SBc4l(l)',
#        'SBb4t(u)', 'Sc1t(o)', 'SBb4l(d)', 'Sb+m(m)', 'Sd?m(o)',
#        'SBb4l(i)', 'SBd2l(o)', 'SBb1m(i)', 'SBb?t(l)', 'SBc+m(r)',
#        'Sa+t(r)', 'Sa1l(m)', 'Sa2l(m)', 'SBc3l(r)', 'SBb1t(d)', 'SBa(m)',
#        'Sa?m(o)', 'SBc+t(d)', 'Sa2l(o)', 'Sb3m(u)', 'Sd1m(d)', 'SBb+m(r)',
#        'SBc2l(u)', 'Sb+l(l)', 'SBc+m(i)', 'Sd3l', 'SBd1m', 'SBd1l',
#        'Sb+l(m)', 'Sen(r)', 'Sb2t(u)', 'Sa(i)', 'SBb2t(i)', 'SBc?m(u)',
#        'Sc4t(l)', 'Sd2l(m)', 'SBb1m(o)', 'SBc4l(d)', 'SBd?l(i)',
#        'Sd4l(i)', 'Sd2l(o)', 'Sd4l(m)', 'Sb+m(d)', 'Sd1t(o)', 'Sb1m(u)',
#        'SBa?t(r)', 'SBc1t(u)', 'Sd1l(d)', 'Sb4t(i)', 'SBd1m(i)',
#        'Sb?m(l)', 'SBc?l(m)', 'Sa2t(o)', 'SBc2t(l)', 'Sc1m(l)',
#        'SBd2t(i)', 'Sb1t(l)', 'Sen(d)', 'SBb4t(l)', 'SBc1l(o)', 'SBb(l)',
#        'Sd3l(i)', 'SBb?l(m)', 'Sc4t(m)', 'Sc+t(l)', 'SBc4m(r)', 'Sc+l(o)',
#        'Sc+m(m)', 'SBb+t(d)', 'SBb1t(u)', 'Sa1m(r)', 'SBc?t(l)',
#        'SBb+m(o)', 'SBb3m(d)', 'SBb3t(d)', 'SBd4t', 'SBc+m(m)',
#        'SBb+l(m)', 'SBa3l(r)', 'SBa2t(r)', 'Sa2m(r)', 'Sc3m(l)',
#        'SBc3t(l)', 'Sa1l(d)', 'Sb+t(d)', 'Sd+m', 'SBb1m(d)', 'Sd+t(d)',
#        'SBb1t(i)', 'Ec(l)', 'SBc3m(l)', 'SBa?t(o)', 'SBd+t', 'Sc+m(r)',
#        'Sa?l', 'Sa?t(o)', 'Sa+m', 'Sa1l(i)', 'SBb2m(u)', 'Sd1t(m)',
#        'Sc+l(m)', 'Sc4t(u)', 'SBd?m(d)', 'SBd1l(i)', 'SBc1m(u)',
#        'SBb4m(d)', 'SBa1l(u)', 'SBc2l(l)', 'SBb1t(l)', 'SBd4l(i)',
#        'Sc3l(o)', 'Sb4m(i)', 'SBa(o)', 'Sb3m(l)', 'SBc3l(m)', 'Sc?m(l)',
#        'SBd2m(m)', 'SBd1t(i)', 'Sc+l(i)', 'SBb?l(d)', 'Sb+t(i)',
#        'Sb4l(d)', 'SBd3l(i)', 'SBd+m(i)', 'SBc+l(o)', 'SBc4t(l)', 'Sa(l)',
#        'Sd1m(m)', 'Sc3l(m)', 'Sa2l(r)', 'SBa2m(r)', 'SBb+m(m)', 'Sd1t(r)',
#        'SBa(d)', 'SBd2m(o)', 'SBb3t(o)', 'SBb1t(o)', 'SBd?t(o)',
#        'Sd+m(o)', 'Sd2l(r)', 'Sc3l(u)', 'Sd?t(m)', 'Sa3l(i)', 'SBa2l(r)',
#        'SBd2t(r)', 'Sa1m(i)', 'Sd1l(m)', 'SBa?m(m)', 'Sa2m(m)', 'Sd3t(i)',
#        'SBa(i)', 'SBc4t(o)', 'Seb(i)', 'Sd2t(m)', 'SBc+m(d)', 'SBd?t(d)',
#        'SBc1m(o)', 'SBc+l(i)', 'SBc3l(o)', 'SBd3t(d)', 'Sa?l(r)',
#        'SBb+l(i)', 'SBb?l(l)', 'SBb1l(l)', 'Sa3l(r)', 'SBa2t', 'SBa1l',
#        'SBb3l(m)', 'SBc4t(u)', 'Sd2m(r)', 'SBb+m(i)', 'Sd1m(o)',
#        'SBa+t(o)', 'Sd1l(r)', 'Sa?m(m)', 'SBb4m(o)', 'SBd+t(r)',
#        'SBb4t(d)', 'Sa2l(d)', 'SBb2l(l)', 'SBb4l(r)', 'Sa1m(o)',
#        'Sa?l(i)', 'Sa+l', 'Sb+l(r)', 'Sd(l)', 'Sc4m(l)', 'SBd3l', 'Sa3m',
#        'SBc4l(r)', 'SBb3t(l)', 'SBa2t(l)', 'SBa2t(i)', 'SBd1m(m)',
#        'SBc1l(l)', 'SBb2t(l)', 'SBb3l(d)', 'Sd2m(d)', 'SBa2m(i)',
#        'Seb(u)', 'Sb3t(u)', 'Sa?t(d)', 'SBd(u)', 'SBd1l(o)', 'Sb+t(u)',
#        'Sb4m(u)', 'SBc4l(m)', 'SBc1m(l)', 'SBa+t', 'SBc4m(m)', 'Sd3t(o)',
#        'Sb4l(m)', 'Sd1m(r)', 'SBb2t(u)', 'SBa3t', 'Sa1l', 'SBd?l(o)',
#        'SBd+t(i)', 'Sa4t', 'SBc+l(m)', 'Sd3m(o)', 'SBd1l(m)', 'Sa4l',
#        'Sc4l(d)', 'SBd2m(u)', 'SBb4t(o)', 'SBa+m', 'SBb4l(m)'],
#       dtype=object)

# %%
df['new_col'] = df['gz2_class'].astype(str).str[0:3]
df['new_col'] = df['new_col'].str.replace('\d+', '')
df['new_col'] = df['new_col'].str.replace('\W', '')
df['new_col'] = df['new_col'].str.replace('Seb', 'Se')
df['new_col'] = df['new_col'].str.replace('Sen', 'Se')
df['new_col'] = df['new_col'].str.replace('Ser', 'Se')
df
# Out:
# <ipython-input-14-fa5cb024f9f7>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['new_col'] = df['new_col'].str.replace('\d+', '')
# <ipython-input-14-fa5cb024f9f7>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['new_col'] = df['new_col'].str.replace('\W', '')
#                      OBJID  ASSEST_ID          RA       DEC gz2_class  \
# 0       587731186203885750     278415    0.006464 -0.092593      Sb2l
# 1       587731187277693072     280232    0.019752  0.781716     SBc2m
# 2       588015510343123099     294272    0.029687  0.857908        Sc
# 3       587731186203951236     278417    0.032579 -0.040578      Sb?t
# 4       587731187277693087     280233    0.042151  0.634290        Ei
# ...                    ...        ...         ...       ...       ...
# 239692  587731187277627616     280223  359.967256  0.671613        Ei
# 239693  587731186740756649     279393  359.969490  0.333354      Sc2m
# 239694  588015509806252115     293021  359.973925  0.556181      Sb2t
# 239695  587731187277627630     280224  359.984922  0.675102     Ei(o)
# 239696  587731187277627636     280225  359.988841  0.715114        Ei
#
#         GZ1_MORPHOLOGY  STAR_FORMING  AGN_LINER  PETROR50_R  PETROR90_R  ...  \
# 0                    0             0          0    1.552346    4.724314  ...
# 1                    0             0          0    4.174540    9.485429  ...
# 2                    0             0          0    1.805935    5.665029  ...
# 3                    0             0          1    4.040482   11.246556  ...
# 4                    0             0          0    1.878149    4.611546  ...
# ...                ...           ...        ...         ...         ...  ...
# 239692               4             0          0    2.209229    5.250726  ...
# 239693               4             0          0    3.130419    6.483614  ...
# 239694               4             0          0    3.303175    9.889430  ...
# 239695               0             0          0    1.966789    6.132270  ...
# 239696               0             0          0    2.385262    7.233043  ...
#
#         PETROMAG_MU  PETROMAG_MG  PETROMAG_MR  PETROMAG_MI  PETROMAG_MZ  \
# 0        -18.451681   -20.106420   -20.834558   -21.150173   -21.371984
# 1        -19.804232   -21.529858   -22.282389   -22.643412   -22.916601
# 2        -18.846533   -20.506390   -21.243180   -21.584341   -21.863384
# 3        -18.629040   -19.668825   -20.125076   -20.315216   -20.470337
# 4        -17.928638   -19.356077   -20.070858   -20.395535   -20.669110
# ...             ...          ...          ...          ...          ...
# 239692   -18.989813   -20.305210   -20.978706   -21.284754   -21.504791
# 239693   -19.709562   -20.810030   -21.346203   -21.586780   -21.781790
# 239694   -20.075562   -21.657505   -22.350897   -22.666334   -22.908318
# 239695   -19.253954   -21.126196   -21.886639   -22.268350   -22.547771
# 239696   -18.821735   -20.540117   -21.284680   -21.635927   -21.787445
#
#         PETROR50_R_KPC  PETROR50_R_KPC_SIMPLE_BIN  PETROMAG_MR_SIMPLE_BIN  \
# 0             2.294145                         22                      63
# 1             6.329214                         63                      34
# 2             2.774615                         27                      55
# 3             1.929550                         19                      77
# 4             1.977281                         19                      78
# ...                ...                        ...                     ...
# 239692        3.384962                         33                      60
# 239693        4.751741                         47                      53
# 239694        5.018529                         50                      32
# 239695        3.130471                         31                      42
# 239696        3.763274                         37                      54
#
#         REDSHIFT_SIMPLE_BIN  new_col
# 0                         6       Sb
# 1                         7      SBc
# 2                         7       Sc
# 3                         1       Sb
# 4                         4       Ei
# ...                     ...      ...
# 239692                    7       Ei
# 239693                    7       Sc
# 239694                    7       Sb
# 239695                    7       Ei
# 239696                    7       Ei
#
# [239697 rows x 33 columns]

# %%
df.new_col.unique()
# Out:
# array(['Sb', 'SBc', 'Sc', 'Ei', 'SBb', 'Er', 'Se', 'SBd', 'Ec', 'Sa',
#        'Sd', 'A', 'SBa'], dtype=object)

# %%
X_tr, X_te, y_tr, y_te = train_test_split(df[['PETROR50_R','PETROR90_R','PETROMAG_U','PETROMAG_G',
                                              'PETROMAG_R','PETROMAG_I','PETROMAG_Z','PSFMAG_R','FIBERMAG_R','DEVMAG_R',
                                              'EXPMAG_R','FRACDEV_R','MU50_R','CMODELMAG_R','REDSHIFT','PETROMAG_MU',
                                              'PETROMAG_MG','PETROMAG_MR','PETROMAG_MI','PETROMAG_MZ','PETROR50_R_KPC']], 
                                              df['GZ1_MORPHOLOGY'], test_size = 0.2, random_state = 42)

# %%
rf = RandomForestClassifier(n_estimators = 20, max_depth = 10, oob_score = True)
#n_estimators = 20, max_depth = 10, max_features didnt matter
rf.fit(X_tr, y_tr)
y_pr = rf.predict(X_te)
err = np.mean(y_pr != y_te)
err, 1 - rf.oob_score_
# Out:
# (0.2841677096370463, 0.2886935027143729)

# %%
rf.feature_names = list(X_tr.columns.values)
print(rf.feature_names)
# Out:
# ['STAR_FORMING', 'AGN_LINER', 'PETROR50_R', 'PETROR90_R', 'PETROMAG_U', 'PETROMAG_G', 'PETROMAG_R', 'PETROMAG_I', 'PETROMAG_Z', 'PSFMAG_R', 'FIBERMAG_R', 'DEVMAG_R', 'EXPMAG_R', 'FRACDEV_R', 'MU50_R', 'CMODELMAG_R', 'REDSHIFT', 'PETROMAG_MU', 'PETROMAG_MG', 'PETROMAG_MR', 'PETROMAG_MI', 'PETROMAG_MZ', 'PETROR50_R_KPC']

# %%
rf_df = pd.DataFrame(columns=['Features', 'Importance'])
rf_df['Features'] = rf.feature_names
rf_df['Importance'] = rf.feature_importances_
rf_df = rf_df.sort_values(by = 'Importance', ascending = False, ignore_index = True)
rf_df
# Out:
#           Features  Importance
# 0        FRACDEV_R    0.075059
# 1       PETROR50_R    0.068127
# 2           MU50_R    0.059884
# 3       PETROR90_R    0.059501
# 4      PETROMAG_MZ    0.059325
# 5         PSFMAG_R    0.058200
# 6      PETROMAG_MI    0.051888
# 7       PETROMAG_U    0.049794
# 8      PETROMAG_MR    0.046829
# 9   PETROR50_R_KPC    0.044968
# 10      FIBERMAG_R    0.043842
# 11      PETROMAG_Z    0.043081
# 12        EXPMAG_R    0.040212
# 13     PETROMAG_MG    0.039543
# 14      PETROMAG_G    0.039490
# 15     PETROMAG_MU    0.038904
# 16        DEVMAG_R    0.038520
# 17      PETROMAG_I    0.036440
# 18        REDSHIFT    0.035331
# 19     CMODELMAG_R    0.035051
# 20      PETROMAG_R    0.033509
# 21       AGN_LINER    0.001274
# 22    STAR_FORMING    0.001228

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.barh(rf_df.Features[0:30], rf_df.Importance[0:30])
ax.set_xlabel('Importance', fontsize = 14)
ax.set_ylabel('Feature', fontsize = 14)
ax.invert_yaxis()
plt.title("Feature Importances in Random Forest", fontsize = 14)
plt.show()

# %%
'STAR_FORMING','AGN_LINER','PETROR50_R','PETROR90_R','PETROMAG_U','PETROMAG_G',
                                                        'PETROMAG_R','PETROMAG_I','PETROMAG_Z','PSFMAG_R','FIBERMAG_R','DEVMAG_R',
                                                        'EXPMAG_R','FRACDEV_R','MU50_R','CMODELMAG_R','REDSHIFT','PETROMAG_MU',
                                                        'PETROMAG_MG','PETROMAG_MR','PETROMAG_MI','PETROMAG_MZ','PETROR50_R_KPC'

# %% [markdown]
# ### Grid Search

# %%
rf.get_params()

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]

# Number of features to consider at every split
max_features = ['auto', 'sqrt']

# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)

# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]

# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]

# Method of selecting samples for training each tree
bootstrap = [True, False]

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

print(random_grid)

# %%
rf = RandomForestRegressor()
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)
rf_random.fit(X_tr, y_tr)

# %%
rf_random.best_params_

# %%
def evaluate(model, test_features, test_labels):
    predictions = model.predict(test_features)
    errors = abs(predictions - test_labels)
    mape = 100 * np.mean(errors / test_labels)
    accuracy = 100 - mape
    print('Model Performance')
    print('Average Error: {:0.4f} degrees.'.format(np.mean(errors)))
    print('Accuracy = {:0.2f}%.'.format(accuracy))
    
    return accuracy

base_model = RandomForestRegressor(n_estimators = 10, random_state = 42)
base_model.fit(train_features, train_labels)
base_accuracy = evaluate(base_model, test_features, test_labels)

best_random = rf_random.best_estimator_
random_accuracy = evaluate(best_random, test_features, test_labels)

print('Improvement of {:0.2f}%.'.format( 100 * (random_accuracy - base_accuracy) / base_accuracy))

# %%
# 10-Fold Cross validation
print np.mean(cross_val_score(clf, X_train, y_train, cv=10))
